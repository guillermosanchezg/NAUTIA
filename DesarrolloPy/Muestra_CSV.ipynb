# %%
import pandas as pd
import os

# %%
def dfFix(df,col1,col2):
    result = df
    x = result.columns.get_loc(col1)
    result.drop(result.columns[:x],axis = 1, inplace = True)
    y = result.columns.get_loc(col2)
    result.drop(result.columns[y+1:],axis = 1, inplace = True)
    return result

# %%
data_Bibliography= pd.read_csv("C:/Users/guill/Documents/Universidad/PlataformaRefugiados/NAUTIA/DesarrolloPy/DataSetOriginales/Bibliography_111019.csv",sep = ";")
data_Bibliography = dfFix(data_Bibliography,"GENERAL INFORMATION - COUNTRY LEVEL","Unnamed: 3")
data_Bibliography.columns = ['GeneralInfo', 'CommunityCountry', 'RefugeeCountry']
data_Bibliography = data_Bibliography.transpose()

# %%
pd.options.display.max_columns = None

# %%
data_Bibliography.head(10)
# Out:
#                                        0               1    \
# GeneralInfo                     Population  Country's name
# CommunityCountry  Host community's country         Etiopia
# RefugeeCountry           Refugees' country         Eritrea
#
#                                         2                              3    \
# GeneralInfo       Number of inhabitants (#)  Men, younger than 5 years (%)
# CommunityCountry                  105000000                             20
# RefugeeCountry                      4475000                             10
#
#                                            4                            5    \
# GeneralInfo       Women between 5-17 years (%)  Men, between 5-17 years (%)
# CommunityCountry                            10                           10
# RefugeeCountry                              20                           20
#
#                                            6                           7    \
# ...

# %%
data_Entities = pd.read_csv("C:/Users/guill/Documents/Universidad/PlataformaRefugiados/NAUTIA/DesarrolloPy/DataSetOriginales/NAUTIA_1_0_Entities_Interview_results.csv",sep = ",")

# %%
data_Entities.head(10)
# Out:
# Empty DataFrame
# ...

# %%
data_Shelter = pd.read_csv("C:/Users/guill/Documents/Universidad/PlataformaRefugiados/NAUTIA/DesarrolloPy/DataSetOriginales/NAUTIA_1_0_Shelter_results.csv",sep = ",")

# %%
data_Shelter.head(2)
# Out:
#                      start                      end Type_of_setlement  \
# 0   2019-11-26 10:19:45.77  2019-11-26 10:32:26.612      refugee_camp
# 1  2019-11-26 10:39:55.362    2019-11-26 10:51:40.2      refugee_camp
#
#   Type_of_Host_Community  Location:Latitude  Location:Longitude  \
# 0         hostcommunityA          27.495314           -7.823158
# 1         hostcommunityA          27.495378           -7.820379
#
#    Location:Altitude  Location:Accuracy Construc_tion_Details:Appropiate_Roof  \
# 0         468.135469                8.0                                   yes
# 1         471.515452                8.0                                   yes
#
#   Construc_tion_Details:Structural_Security Construc_tion_Details:Resilient  \
# 0                                       yes                             yes
# 1                                       yes                             yes
#
#   Construc_tion_Details:Ventilation Construc_tion_Details:Humidity  \
# ...

# %%
data_ComunalServices = pd.read_csv("C:/Users/guill/Documents/Universidad/PlataformaRefugiados/NAUTIA/DesarrolloPy/DataSetOriginales/NAUTIA_1_0_Communal_Services_results.csv",sep = ",")

# %%
data_ComunalServices.head(2)
# Out:
#                      start                      end  \
# 0  2019-11-18 10:45:24.364  2019-11-18 18:46:50.261
# 1  2019-11-17 21:48:18.876  2019-11-18 18:52:07.268
#
#   General_Information:Type_of_setlement  \
# 0                          refugee_camp
# 1                          refugee_camp
#
#    General_Information:Type_of_Host_Community  \
# 0                                         NaN
# 1                                         NaN
#
#    General_Information:Record_your_current_location:Latitude  \
# 0                                                NaN
# 1                                                NaN
#
#    General_Information:Record_your_current_location:Longitude  \
# 0                                                NaN
# 1                                                NaN
#
#    General_Information:Record_your_current_location:Altitude  \
# 0                                                NaN
# 1                                                NaN
#
# ...

# %%
data_LocalLeader = pd.read_csv("C:/Users/guill/Documents/Universidad/PlataformaRefugiados/NAUTIA/DesarrolloPy/DataSetOriginales/NAUTIA_1_0_Local_leaders_v3_results.csv",sep = ",")

# %%
data_LocalLeader
# Out:
# Empty DataFrame
# Columns: [start, end, General:gender, General:settlement, General:Name_host_community, Settlement_security:secur_committees, Food_security:cultivation_months, Food_security:own_food_months, Food_security:kind_food, Food_security:fertilizers, Food_security:storing_food, Food_security:dry_food, Food_security:perishable_food, Food_security:Grazing_technique, Costs:basic_basket, Costs:cost_basic_basket, Costs:cost_firewood, Costs:diesel_gensest, Costs:money_electricity, Costs:cost_solarpanels, Costs:cost_solar_panel, meta:instanceID]
# Index: []
