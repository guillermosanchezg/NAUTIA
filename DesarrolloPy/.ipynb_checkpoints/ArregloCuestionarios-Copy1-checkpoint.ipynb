# %%
import pandas as pd
import os
mainpath = "C:/Users/guill/Documents/Universidad/PlataformaRefugiados/NAUTIA/DesarrolloPy/DataSetOriginales"
filename = "Shimelba_HostCommunity_Survey_results.csv"
fullpath = os.path.join(mainpath, filename)

# %%
data = pd.read_csv(fullpath)

# %%
data.head(2)
# Out:
#   group_lj1dr54:female_male  group_lj1dr54:age  \
# 0                    female                 32
# 1                    female                 37
#
#   group_lj1dr54:refugee_community  \
# 0                       community
# 1                       community
#
#   group_lj1dr54:_4_Choose_the_name_of_the_host  \
# 0                                     shimelba
# 1                                     shimelba
#
#    group_lj1dr54:Specify_the_name_of_the_host_community  \
# 0                                                NaN
# 1                                                NaN
#
#   group_lj1dr54:_1_5_Choose_the_ethnic_group_o  \
# 0                                     tigrinya
# 1                                     tigrinya
#
#   group_lj1dr54:Write_the_other_ethnic_group  \
# 0                                        NaN
# 1                                        NaN
#
#   group_on1ls06:_2_1_Are_you_the_fam_ly_head_of_your_home  \
# ...

# %%
df = data

# %%
for column in df.columns:
    if column == "group_lj1dr54:_4_Choose_the_name_of_the_host":
        x = df.columns.get_loc("group_lj1dr54:_4_Choose_the_name_of_the_host")
    else: 
        if  column == "group_lj1dr54:age":
            y = df.columns.get_loc("group_on1ls06:_2_1_Are_you_the_fam_ly_head_of_your_home")
            
df.drop(df.columns[0:x],axis = 1, inplace = True)
df.drop(df.columns[y-1:],axis = 1, inplace = True)

# %%
df.head(2)
# Out:
#   group_lj1dr54:refugee_community  \
# 0                       community
# 1                       community
#
#   group_lj1dr54:_4_Choose_the_name_of_the_host  \
# 0                                     shimelba
# 1                                     shimelba
#
#    group_lj1dr54:Specify_the_name_of_the_host_community  \
# 0                                                NaN
# 1                                                NaN
#
#   group_lj1dr54:_1_5_Choose_the_ethnic_group_o  \
# 0                                     tigrinya
# 1                                     tigrinya
#
#   group_lj1dr54:Write_the_other_ethnic_group  \
# 0                                        NaN
# 1                                        NaN
#
#   group_on1ls06:_2_1_Are_you_the_fam_ly_head_of_your_home  \
# 0                                                 no
# 1                                                yes
#
#    group_on1ls06:number_people  group_on1ls06:number_adults
# ...
